# %%
print('sys.executable')
# Out:
# sys.executable

# %%
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/3c/a1/accf6d4f0c80c5d9ba9735d6b1550e444180599f34dec69ca01360f717ad/numpy-2.5.3-cp312-cp312-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB 435.7 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/12.6 MB 762.6 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/12.6 MB 731.4 kB/s eta 0:00:18
#     --------------------------------------- 0.2/12.6 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.3/12.6 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.3/12.6 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/12.6 MB 1.2 MB/s eta 0:00:10
# ...

# %%
import numpy as np

image = np.array([
    [0, 50, 100],
    [150, 200, 250],
    [255, 128, 64]
])
print(image)
print("Shape:", image.shape)
print("Data type:", image.dtype)
print("Minimum:", image.min())
print("Maximum:", image.max())
print("Mean:", image.mean())
# Out:
# [[  0  50 100]
#  [150 200 250]
#  [255 128  64]]
# Shape: (3, 3)
# Data type: int64
# Minimum: 0
# Maximum: 255
# Mean: 133.0

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/04/93/0d239bde12b308262265c2d98909b2f0ecad2b5deeae96241642e822e9c7/matplotlib-3.11.2-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      -------------- ----------------------- 30.7/80.3 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 80.3/80.3 kB 752.9 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/50/a9/dab08786bb4d77ef9a046b3c1be923be4e73c5d07d91f5a54e8ea9b09e41/contourpy-1.4.0-cp312-cp312-win_amd64.whl.metadata
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.zeros((400, 400), dtype=np.uint8)

image[100:300, 100:300] = 255

image[130:270, 130:140] = 0
image[130:140, 130:180] = 0
image[130:270, 170:180] = 0
image[130:140, 170:220] = 0

image[130:270, 220:230] = 0

pixels = image.shape[0] * image.shape[1]
print("Number of pixels:", pixels)

plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# Number of pixels: 160000

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open(r"\\192.168.1.10\shear all\lena5.jpg")
image = np.array(img)

print("Shape:", image.shape)
print("Data type:", image.dtype)
print("Minimum:", image.min())
print("Maximum:", image.max())
print("Mean:", image.mean())

plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Shape: (512, 512, 3)
# Data type: uint8
# Minimum: 0
# Maximum: 255
# Mean: 128.09458033243814

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open(r"\\192.168.1.10\shear all\lena5.jpg")

img_gray = img.convert("L")

image = np.array(img_gray)

print("Shape:", image.shape)
print("Data type:", image.dtype)
print("Minimum:", image.min())
print("Maximum:", image.max())
print("Mean:", image.mean())

plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# Shape: (512, 512)
# Data type: uint8
# Minimum: 11
# Maximum: 249
# Mean: 124.04621124267578

# %%
value = 100

count = np.sum(image == value)

print("Number of pixels:", count)
# Out:
# Number of pixels: 961

# %%
red = image[:, :, 0]
green = image[:, :, 1]
blue = image[:, :, 2]

plt.imshow(red, cmap="gray")
plt.title("Red Channel")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 red = image[:, :, 0]
#       2 green = image[:, :, 1]
#       3 blue = image[:, :, 2]
#       4
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(r"C:\Users\PC-LAB1\Downloads\output.png")

# تحويل إلى Grayscale
gray = img.convert("L")

# Histogram
plt.hist(gray.getdata(), bins=256, range=(0, 256))

plt.title("Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\PC-LAB1\AppData\Local\Temp\ipykernel_11784\2508496141.py:10: DeprecationWarning: Image.Image.getdata is deprecated and will be removed in Pillow 14 (2027-10-15). Use get_flattened_data instead.
#   plt.hist(gray.getdata(), bins=256, range=(0, 256))

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# قراءة الصورة
img = Image.open(r"C:\Users\PC-LAB1\Downloads\output.png")

# تحويل إلى Grayscale
gray = np.array(img.convert("L"))

# Histogram Equalization
hist, bins = np.histogram(gray.flatten(), 256, [0, 256])
cdf = hist.cumsum()

# تجاهل القيم الصفرية
cdf_masked = np.ma.masked_equal(cdf, 0)

# معادلة Equalization
cdf_equalized = (cdf_masked - cdf_masked.min()) * 255 / (
    cdf_masked.max() - cdf_masked.min()
)

cdf_equalized = np.ma.filled(cdf_equalized, 0).astype("uint8")

# الصورة بعد Equalization
equalized = cdf_equalized[gray]

# عرض النتائج
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(gray, cmap="gray")
plt.title("Original Image")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.hist(gray.flatten(), bins=256, range=(0, 256))
plt.title("Original Histogram")

plt.subplot(2, 2, 3)
plt.imshow(equalized, cmap="gray")
plt.title("Histogram Equalized")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.hist(equalized.flatten(), bins=256, range=(0, 256))
plt.title("Equalized Histogram")

plt.tight_layout()
plt.show()

# %%
from PIL import Image, ImageEnhance
import matplotlib.pyplot as plt

# قراءة الصورة
img = Image.open(r"C:\Users\PC-LAB1\Downloads\output.png")

# تحويل الصورة إلى Grayscale
gray = img.convert("L")

# تحسين التباين
enhancer = ImageEnhance.Contrast(gray)
contrast_img = enhancer.enhance(2.0)

# عرض الصورة الأصلية والمعدلة
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.imshow(gray, cmap="gray")
plt.title("Original Image")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(contrast_img, cmap="gray")
plt.title("Contrast Enhanced")
plt.axis("off")

# Histogram للصورة الأصلية
plt.subplot(2, 2, 3)
plt.hist(gray.getdata(), bins=256, range=(0, 256))
plt.title("Original Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")

# Histogram بعد تحسين التباين
plt.subplot(2, 2, 4)
plt.hist(contrast_img.getdata(), bins=256, range=(0, 256))
plt.title("Enhanced Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC-LAB1\AppData\Local\Temp\ipykernel_11784\1517595532.py:29: DeprecationWarning: Image.Image.getdata is deprecated and will be removed in Pillow 14 (2027-10-15). Use get_flattened_data instead.
#   plt.hist(gray.getdata(), bins=256, range=(0, 256))
# C:\Users\PC-LAB1\AppData\Local\Temp\ipykernel_11784\1517595532.py:36: DeprecationWarning: Image.Image.getdata is deprecated and will be removed in Pillow 14 (2027-10-15). Use get_flattened_data instead.
#   plt.hist(contrast_img.getdata(), bins=256, range=(0, 256))

# %%
git add .
git commit -m "update project"
git branch -M main
git push -u origin main
